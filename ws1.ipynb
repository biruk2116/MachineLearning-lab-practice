# %%
#                           Question number 1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('dataset/ws1.csv')

plt.plot(df['x'], df['y'])
plt.xlabel('x')
plt.ylabel('y')
plt.title('Line Chart')
plt.show()

# %%
                                  
                                      # Question number 2

df = pd.read_csv('dataset/ws2.csv')

plt.xlabel('Department')
plt.ylabel('Number of Students')
plt.title('Students in Computing College')

plt.bar(df['Department'], df['Students'])

plt.show()

# %%
                              #  Question number 3


data = pd.read_csv('dataset/ws2.csv')

plt.xlabel('Department')
plt.ylabel('No.of Students')
plt.title('Computing College Students')

plt.bar(data['Department'], data['Students'],
        color=('red','green','blue','yellow','orange'))

plt.show()

# %%
                                      
                                       # Question number 4


data = np.random.randn(1000)

plt.hist(data, bins=20, edgecolor='black')

plt.title('Histogram of Randomly Generated Data')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.show()

# Creates a histogram of that data
# X-axis (Value): the number ranges (e.g., -3 to -2, -2 to -1, etc.)
# Y-axis (Frequency): how many numbers fall in each range

# What it does specifically:
# Splits the data into 20 groups (bins)
# Counts how many values fall into each group
# Draws bars to show the frequency distribution

# %%
                            # Question number 5
  # It gives you statistical plots with better defaults (like boxplots)

# Same target → center = 0
# Same number of shots → 100 attempts each
# Same environment → same rules

import seaborn as sns        
data = [np.random.normal(0, std, 100) for std in range(1, 4)]    


sns.boxplot(data=data)

plt.title('Boxplot')
plt.xlabel('Category')
plt.ylabel('Values')

plt.show()

# %%
                                       # Question number 6

import seaborn as sns
data = [np.random.normal(0, std, 100) for std in range(1, 6)]
data
sns.violinplot(data=data)
plt.title ('Violinplot')
plt.xlabel('Category')
plt.ylabel('Values')
plt.show()

# %%
         # Question number 7

data1 = pd.read_csv('dataset/ws1_instructors.csv')

labels = data1['Department'].tolist()
values = data1['Instructors'].tolist()


N = len(labels)

angles = np.linspace(0, 2 * np.pi, N, endpoint=False)

values = np.concatenate((values, [values[0]]))
angles = np.concatenate((angles, [angles[0]]))

labels = labels + [labels[0]]  

plt.figure(figsize=(6, 6))
ax = plt.subplot(111, polar=True)

ax.plot(angles, values, label='Instructors', linewidth=2)


ax.fill(angles, values, alpha=0.3)


ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels[:-1])


plt.title('Radar Chart of Instructors by Department')


plt.legend(loc='upper right')

plt.show()

# %%
 

                                  # Question number 7

import matplotlib.pyplot as plt
import numpy as np
data1=pd.read_csv('dataset/ws1_instructors.csv')
labels=data1['Department']
data=data1['Instructors']

# Create a polar plot
plt.polar(labels, data, color='blue', linewidth=2)

# Add a title
plt.title("Polar Plot Example")

# Display the plot
plt.show()

# %%
                                      # Question number 7

import plotly.express as px
import pandas as pd

df = pd.read_csv('dataset/ws1_instructors.csv')

fig = px.line_polar(df, r='Instructors', theta='Department', line_close=True)

fig.show()

# %%
                #  question  number 8


Data = pd.read_csv('dataset/ws1_area_chart.csv')

plt.fill_between(Data['x'], Data['y1'], Data['y2'],
                 color='skyblue', alpha=0.4)

plt.title('Area Chart')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %%
                             
                #  question  number 9

import matplotlib.pyplot as plt
import numpy as np

# Generate x values (angles in radians)

x = np.linspace(-2* np.pi, 2 * np.pi, 400) # From -2pi to 2pi with 400 points
# Calculate y values for sine, cosine, and tangent
y_sin = np.sin(x)
y_cos = np.cos(x)
y_tan = np.tan(x)

# Create a figure and a set of subplots
fig, axes = plt.subplots(3, 1, figsize=(8, 10)) # 3 rows, 1 column

# Plot sine function in the first subplot
axes[0].plot(x, y_sin, label='sin(x)', color='blue')
axes[0].set_title('Sine Function')
axes[0].set_ylabel('sin(x)')
axes[0].grid(True)
axes[0].legend()

# Plot cosine function in the second subplot
axes[1].plot(x, y_cos, label='cos(x)', color='green')
axes[1].set_title('Cosine Function')
axes[1].set_ylabel('cos(x)')
axes[1].grid(True)
axes[1].legend()

# Plot tangent function in the third subplot
# Handle asymptotes for tangent by setting y-limits
axes[2].plot(x, y_tan, label='tan(x)', color='red')
axes[2].set_title('Tangent Function')
axes[2].set_xlabel('Angle (radians)')
axes[2].set_ylabel('tan(x)')
axes[2].set_ylim(-10, 10) # Limit y-axis to avoid extreme values near asymptotes
axes[2].grid(True)
axes[2].legend()

# Adjust layout to prevent overlapping titles/labels
plt.tight_layout()

# Display the plot
plt.show()
