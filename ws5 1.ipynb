# %%
#1 Simple Linear regression
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error

data = pd.read_csv('dataset/ws5que1.csv')
print(data)
print("\nsize of the dataset", data.shape)
# %matplotlib inline
plt.xlabel('Advertising (in Birr)')
plt.ylabel('Sales (in Birr)')
plt.scatter(data.Advertising,data.Sales,color='red',marker='*')
X = data.drop('Sales',axis='columns')
Y=data.Sales
# Out:
#     Advertising  Sales
# 0           1.8    104
# 1           1.2     68
# 2           0.4     39
# 3           0.5     43
# 4           2.5    127
# 5           2.5    134
# 6           1.5     87
# 7           1.2     77
# 8           1.6    102
# 9           1.0     65
# 10          1.5    101
# 11          0.7     46
# 12          1.0     52
# 13          0.8     33
#
# size of the dataset (14, 2)

# %%
# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(data[['Advertising']],data.Sales)
print (reg.predict([[1.5]]))
print (reg.predict([[2]]))
print ("Slope = ", reg.coef_)
print ("X-intercep = ", reg.intercept_)
y=reg.coef_*1.5+reg.intercept_
print(y)
Y_calculated = reg.predict(X)
print ("\n\n Predicted Value \n ", Y_calculated)
print (Y_calculated.shape)
print ("\n\n Actual Value \n ", Y)
residual=Y-Y_calculated
print ("\n\n Residual (Error) \n", residual)
data['SalesCalculated']=reg.predict(X)
print (data)
data['residual'] = data.Sales - data.SalesCalculated
print (data)
print ("\n \n Mean Absolute Error (MAE): ", mean_absolute_error(data.Sales, data.SalesCalculated))
print ("\n \n Mean Squared Error (MSE): ", mean_squared_error(data.Sales, data.SalesCalculated))
print ("\n \n Root Mean Squared Error (RMSE):  ", root_mean_squared_error(data.Sales, data.SalesCalculated))
# Out:
# [86.71942446]
# [111.01798561]
# Slope =  [48.5971223]
# X-intercep =  13.823741007194236
# [86.71942446]
#
#
#  Predicted Value
#   [101.29856115  72.14028777  33.26258993  38.12230216 135.31654676
#  135.31654676  86.71942446  72.14028777  91.57913669  62.42086331
#   86.71942446  47.84172662  62.42086331  52.70143885]
# (14,)
#
#
#  Actual Value
#   0     104
# 1      68
# 2      39
# 3      43
# 4     127
# 5     134
# 6      87
# 7      77
# 8     102
# 9      65
# 10    101
# 11     46
# 12     52
# 13     33
# Name: Sales, dtype: int64
#
#
#  Residual (Error)
#  0      2.701439
# 1     -4.140288
# 2      5.737410
# 3      4.877698
# 4     -8.316547
# 5     -1.316547
# 6      0.280576
# 7      4.859712
# 8     10.420863
# 9      2.579137
# 10    14.280576
# 11    -1.841727
# 12   -10.420863
# 13   -19.701439
# Name: Sales, dtype: float64
#     Advertising  Sales  SalesCalculated   residual
# 0           1.8    104       101.298561   2.701439
# 1           1.2     68        72.140288  -4.140288
# 2           0.4     39        33.262590   5.737410
# 3           0.5     43        38.122302   4.877698
# 4           2.5    127       135.316547  -8.316547
# 5           2.5    134       135.316547  -1.316547
# 6           1.5     87        86.719424   0.280576
# 7           1.2     77        72.140288   4.859712
# 8           1.6    102        91.579137  10.420863
# 9           1.0     65        62.420863   2.579137
# 10          1.5    101        86.719424  14.280576
# 11          0.7     46        47.841727  -1.841727
# 12          1.0     52        62.420863 -10.420863
# 13          0.8     33        52.701439 -19.701439
#     Advertising  Sales  SalesCalculated   residual
# 0           1.8    104       101.298561   2.701439
# 1           1.2     68        72.140288  -4.140288
# 2           0.4     39        33.262590   5.737410
# 3           0.5     43        38.122302   4.877698
# 4           2.5    127       135.316547  -8.316547
# 5           2.5    134       135.316547  -1.316547
# 6           1.5     87        86.719424   0.280576
# 7           1.2     77        72.140288   4.859712
# 8           1.6    102        91.579137  10.420863
# 9           1.0     65        62.420863   2.579137
# 10          1.5    101        86.719424  14.280576
# 11          0.7     46        47.841727  -1.841727
# 12          1.0     52        62.420863 -10.420863
# 13          0.8     33        52.701439 -19.701439
#
#
#  Mean Absolute Error (MAE):  6.533915724563208
#
#
#  Mean Squared Error (MSE):  71.07553956834533
#
#
#  Root Mean Squared Error (RMSE):   8.430631030257778
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
