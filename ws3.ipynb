# %%
# Solution on Data Preprocessing Exercise
# 1. Deliberately change the value of data to missing value in each feature of the dataset

import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer, KNNImputer

# Load the dataset
data11 = pd.read_csv('dataset/iris.csv')

iris_df = data11.iloc[:, :-1]

np.random.seed(42)  

for col in iris_df.columns:
    missing_indices = np.random.choice(iris_df.index, size=10, replace=False)
    iris_df.loc[missing_indices, col] = np.nan

print("DataFrame with missing values:")
print(iris_df)
# Out:
# DataFrame with missing values:
#      5.1  3.5  1.4  0.2
# 0    4.9  3.0  1.4  0.2
# 1    4.7  3.2  1.3  0.2
# 2    4.6  3.1  1.5  0.2
# 3    5.0  3.6  1.4  0.2
# 4    5.4  3.9  1.7  0.4
# ..   ...  ...  ...  ...
# 144  6.7  3.0  5.2  NaN
# 145  6.3  2.5  5.0  1.9
# 146  6.5  3.0  5.2  2.0
# 147  6.2  3.4  5.4  2.3
# 148  5.9  3.0  5.1  1.8
#
# [149 rows x 4 columns]

# %%
                    # 2.Impute the missing value data with mean value of the corresponding feature value

import pandas as pd

print("\nMissing values before imputation:")
print(iris_df.isnull().sum())

# Instead of using inplace=True
for col in iris_df.select_dtypes(include=['number']).columns:
    mean_value = iris_df[col].mean()
    iris_df[col] = iris_df[col].fillna(mean_value)   

print("\nDataFrame after mean imputation (numeric columns only):")
print(iris_df.head())
print("\nMissing values after imputation:")
print(iris_df.isnull().sum())

# Step 2: Assign Class column from data11
iris_df['Class'] = data11.iloc[:, 4]  # 5th column from data11

print("\nDataFrame after adding 'Class' column:")
print(iris_df.head())
# Out:
# Missing values before imputation:
# 5.1    10
# 3.5    10
# 1.4    10
# 0.2    10
# dtype: int64
#
# DataFrame after mean imputation (numeric columns only):
#    5.1  3.5  1.4  0.2
# 0  4.9  3.0  1.4  0.2
# 1  4.7  3.2  1.3  0.2
# 2  4.6  3.1  1.5  0.2
# 3  5.0  3.6  1.4  0.2
# 4  5.4  3.9  1.7  0.4
#
# Missing values after imputation:
# 5.1    0
# 3.5    0
# 1.4    0
# 0.2    0
# dtype: int64
#
# DataFrame after adding 'Class' column:
#    5.1  3.5  1.4  0.2        Class
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
                      # 3.Adjust the precision to 2 round off. 

# code to round ofto 3 decimal place
iris_df=iris_df.round(3)
print(iris_df)
data=np.concatenate((iris_df,data11),axis=1)
print(data)
# Out:
#      5.1  3.5  1.4    0.2           Class
# 0    4.9  3.0  1.4  0.200     Iris-setosa
# 1    4.7  3.2  1.3  0.200     Iris-setosa
# 2    4.6  3.1  1.5  0.200     Iris-setosa
# 3    5.0  3.6  1.4  0.200     Iris-setosa
# 4    5.4  3.9  1.7  0.400     Iris-setosa
# ..   ...  ...  ...    ...             ...
# 144  6.7  3.0  5.2  1.196  Iris-virginica
# 145  6.3  2.5  5.0  1.900  Iris-virginica
# 146  6.5  3.0  5.2  2.000  Iris-virginica
# 147  6.2  3.4  5.4  2.300  Iris-virginica
# 148  5.9  3.0  5.1  1.800  Iris-virginica
#
# [149 rows x 5 columns]
# [[4.9 3.0 1.4 ... 1.4 0.2 'Iris-setosa']
#  [4.7 3.2 1.3 ... 1.3 0.2 'Iris-setosa']
#  [4.6 3.1 1.5 ... 1.5 0.2 'Iris-setosa']
#  ...
#  [6.5 3.0 5.2 ... 5.2 2.0 'Iris-virginica']
#  [6.2 3.4 5.4 ... 5.4 2.3 'Iris-virginica']
#  [5.9 3.0 5.1 ... 5.1 1.8 'Iris-virginica']]

# %%
# 4.Impute the missing value data with most frequent value of the corresponding feature

from sklearn.impute import SimpleImputer  

data2 = pd.read_csv('dataset/irisMissingValue.csv')

# Check last few rows and missing values
print(data2.tail())
print(round(data2.isnull().sum(), 2).sort_values(ascending=False))

# Impute missing values with most frequent value
imp_mode = SimpleImputer(strategy='most_frequent')  
data2_imputed = imp_mode.fit_transform(data2)       

# Convert back to DataFrame to keep column names
data2_imputed = pd.DataFrame(data2_imputed, columns=data2.columns)

print("\nData after imputing most frequent value:\n")
print(data2_imputed.tail())
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  NaN  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 5.1            10
# 3.5            10
# 1.4            10
# 0.2            10
# Iris-setosa     0
# dtype: int64
#
# Data after imputing most frequent value:
#
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  0.2  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica

# %%
#             5.Impute the missing value data with a constant value 100 to every corresponding feature

#  Imputation with constant vales
data2 = pd.read_csv('dataset/irisMissingValue.csv')
print (data2.tail())
print (round(data2.isnull().sum(), 2).sort_values(ascending=False))
imputer = SimpleImputer(strategy='constant', fill_value=100)
imp_cons=imputer
imp_cons.fit(data2)
data2=imp_cons.transform(data2)
print (data2)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 144  6.7  3.0  5.2  NaN  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
# 5.1            10
# 3.5            10
# 1.4            10
# 0.2            10
# Iris-setosa     0
# dtype: int64
# [[4.9 3.0 1.4 0.2 'Iris-setosa']
#  [4.7 3.2 1.3 0.2 'Iris-setosa']
#  [4.6 3.1 1.5 0.2 'Iris-setosa']
#  [5.0 3.6 1.4 0.2 'Iris-setosa']
#  [5.4 3.9 1.7 0.4 'Iris-setosa']
#  [4.6 3.4 1.4 100 'Iris-setosa']
#  [5.0 3.4 1.5 0.2 'Iris-setosa']
#  [4.4 2.9 1.4 0.2 'Iris-setosa']
#  [4.9 3.1 1.5 0.1 'Iris-setosa']
#  [5.4 100 1.5 0.2 'Iris-setosa']
#  [4.8 3.4 100 0.2 'Iris-setosa']
#  [4.8 3.0 1.4 0.1 'Iris-setosa']
#  [4.3 3.0 1.1 0.1 'Iris-setosa']
#  [5.8 4.0 1.2 0.2 'Iris-setosa']
#  [5.7 100 1.5 100 'Iris-setosa']
#  [5.4 3.9 1.3 0.4 'Iris-setosa']
#  [5.1 3.5 1.4 0.3 'Iris-setosa']
#  [5.7 3.8 1.7 100 'Iris-setosa']
#  [100 3.8 1.5 0.3 'Iris-setosa']
#  [5.4 3.4 1.7 0.2 'Iris-setosa']
#  [5.1 100 1.5 0.4 'Iris-setosa']
#  [4.6 3.6 1.0 0.2 'Iris-setosa']
#  [5.1 3.3 1.7 0.5 'Iris-setosa']
#  [4.8 3.4 1.9 0.2 'Iris-setosa']
#  [5.0 3.0 1.6 0.2 'Iris-setosa']
#  [5.0 3.4 1.6 0.4 'Iris-setosa']
#  [5.2 3.5 1.5 0.2 'Iris-setosa']
#  [5.2 3.4 1.4 0.2 'Iris-setosa']
#  [4.7 3.2 100 0.2 'Iris-setosa']
#  [4.8 3.1 1.6 0.2 'Iris-setosa']
#  [5.4 3.4 100 0.4 'Iris-setosa']
#  [100 4.1 1.5 0.1 'Iris-setosa']
#  [5.5 4.2 1.4 0.2 'Iris-setosa']
#  [4.9 3.1 1.5 0.1 'Iris-setosa']
#  [5.0 3.2 1.2 0.2 'Iris-setosa']
#  [5.5 3.5 1.3 0.2 'Iris-setosa']
#  [4.9 3.1 1.5 0.1 'Iris-setosa']
#  [4.4 3.0 1.3 0.2 'Iris-setosa']
#  [5.1 3.4 1.5 0.2 'Iris-setosa']
#  [5.0 3.5 1.3 0.3 'Iris-setosa']
#  [4.5 2.3 1.3 0.3 'Iris-setosa']
#  [4.4 3.2 1.3 0.2 'Iris-setosa']
#  [5.0 100 1.6 0.6 'Iris-setosa']
#  [5.1 3.8 1.9 0.4 'Iris-setosa']
#  [4.8 3.0 1.4 0.3 'Iris-setosa']
#  [5.1 100 1.6 0.2 'Iris-setosa']
#  [4.6 100 1.4 0.2 'Iris-setosa']
#  [5.3 100 1.5 0.2 'Iris-setosa']
#  [5.0 3.3 1.4 0.2 'Iris-setosa']
#  [7.0 3.2 4.7 1.4 'Iris-versicolor']
#  [6.4 3.2 4.5 1.5 'Iris-versicolor']
#  [6.9 3.1 4.9 1.5 'Iris-versicolor']
#  [5.5 2.3 4.0 1.3 'Iris-versicolor']
#  [6.5 2.8 4.6 1.5 'Iris-versicolor']
#  [5.7 2.8 4.5 1.3 'Iris-versicolor']
#  [6.3 3.3 4.7 100 'Iris-versicolor']
#  [4.9 2.4 3.3 1.0 'Iris-versicolor']
#  [6.6 2.9 4.6 1.3 'Iris-versicolor']
#  [5.2 2.7 3.9 1.4 'Iris-versicolor']
#  [5.0 2.0 3.5 1.0 'Iris-versicolor']
#  [5.9 3.0 4.2 1.5 'Iris-versicolor']
#  [6.0 2.2 100 1.0 'Iris-versicolor']
#  [6.1 2.9 4.7 1.4 'Iris-versicolor']
#  [5.6 2.9 3.6 1.3 'Iris-versicolor']
#  [100 100 100 1.4 'Iris-versicolor']
#  [5.6 3.0 4.5 1.5 'Iris-versicolor']
#  [5.8 2.7 4.1 1.0 'Iris-versicolor']
#  [6.2 2.2 4.5 1.5 'Iris-versicolor']
#  [100 2.5 3.9 1.1 'Iris-versicolor']
#  [5.9 3.2 100 1.8 'Iris-versicolor']
#  [6.1 2.8 100 1.3 'Iris-versicolor']
#  [6.3 2.5 4.9 1.5 'Iris-versicolor']
#  [6.1 2.8 4.7 1.2 'Iris-versicolor']
#  [100 2.9 4.3 1.3 'Iris-versicolor']
#  [6.6 3.0 4.4 1.4 'Iris-versicolor']
#  [6.8 2.8 4.8 1.4 'Iris-versicolor']
#  [100 3.0 5.0 1.7 'Iris-versicolor']
#  [6.0 100 4.5 1.5 'Iris-versicolor']
#  [100 2.6 3.5 100 'Iris-versicolor']
#  [5.5 2.4 100 1.1 'Iris-versicolor']
#  [5.5 2.4 3.7 1.0 'Iris-versicolor']
#  [5.8 2.7 3.9 1.2 'Iris-versicolor']
#  [100 2.7 5.1 1.6 'Iris-versicolor']
#  [5.4 3.0 4.5 1.5 'Iris-versicolor']
#  [6.0 3.4 4.5 1.6 'Iris-versicolor']
#  [6.7 3.1 4.7 1.5 'Iris-versicolor']
#  [6.3 2.3 4.4 1.3 'Iris-versicolor']
#  [5.6 3.0 4.1 1.3 'Iris-versicolor']
#  [5.5 2.5 4.0 100 'Iris-versicolor']
#  [5.5 2.6 4.4 1.2 'Iris-versicolor']
#  [6.1 3.0 4.6 1.4 'Iris-versicolor']
#  [5.8 2.6 4.0 1.2 'Iris-versicolor']
#  [5.0 2.3 3.3 1.0 'Iris-versicolor']
#  [5.6 2.7 4.2 1.3 'Iris-versicolor']
#  [5.7 3.0 4.2 1.2 'Iris-versicolor']
#  [5.7 2.9 4.2 1.3 'Iris-versicolor']
#  [6.2 2.9 4.3 1.3 'Iris-versicolor']
#  [5.1 2.5 3.0 1.1 'Iris-versicolor']
#  [5.7 2.8 4.1 1.3 'Iris-versicolor']
#  [6.3 3.3 6.0 2.5 'Iris-virginica']
#  [5.8 2.7 5.1 1.9 'Iris-virginica']
#  [7.1 3.0 5.9 2.1 'Iris-virginica']
#  [6.3 2.9 5.6 1.8 'Iris-virginica']
#  [6.5 3.0 5.8 2.2 'Iris-virginica']
#  [7.6 3.0 6.6 2.1 'Iris-virginica']
#  [4.9 2.5 4.5 100 'Iris-virginica']
#  [7.3 2.9 6.3 1.8 'Iris-virginica']
#  [6.7 2.5 5.8 1.8 'Iris-virginica']
#  [7.2 3.6 6.1 2.5 'Iris-virginica']
#  [6.5 3.2 5.1 2.0 'Iris-virginica']
#  [6.4 2.7 5.3 1.9 'Iris-virginica']
#  [6.8 3.0 5.5 2.1 'Iris-virginica']
#  [5.7 2.5 5.0 2.0 'Iris-virginica']
#  [5.8 2.8 5.1 100 'Iris-virginica']
#  [6.4 3.2 5.3 2.3 'Iris-virginica']
#  [6.5 3.0 100 1.8 'Iris-virginica']
#  [7.7 3.8 6.7 2.2 'Iris-virginica']
#  [100 2.6 100 2.3 'Iris-virginica']
#  [6.0 2.2 5.0 1.5 'Iris-virginica']
#  [6.9 3.2 5.7 2.3 'Iris-virginica']
#  [5.6 2.8 4.9 2.0 'Iris-virginica']
#  [7.7 2.8 6.7 2.0 'Iris-virginica']
#  [6.3 100 4.9 1.8 'Iris-virginica']
#  [6.7 3.3 5.7 2.1 'Iris-virginica']
#  [7.2 3.2 6.0 1.8 'Iris-virginica']
#  [6.2 2.8 4.8 1.8 'Iris-virginica']
#  [6.1 3.0 4.9 1.8 'Iris-virginica']
#  [6.4 2.8 5.6 100 'Iris-virginica']
#  [7.2 3.0 5.8 1.6 'Iris-virginica']
#  [7.4 2.8 6.1 1.9 'Iris-virginica']
#  [7.9 3.8 6.4 2.0 'Iris-virginica']
#  [6.4 2.8 5.6 2.2 'Iris-virginica']
#  [6.3 2.8 5.1 1.5 'Iris-virginica']
#  [6.1 2.6 5.6 1.4 'Iris-virginica']
#  [7.7 3.0 6.1 2.3 'Iris-virginica']
#  [6.3 3.4 5.6 2.4 'Iris-virginica']
#  [6.4 3.1 5.5 1.8 'Iris-virginica']
#  [6.0 3.0 4.8 1.8 'Iris-virginica']
#  [6.9 3.1 5.4 2.1 'Iris-virginica']
#  [6.7 3.1 5.6 2.4 'Iris-virginica']
#  [100 3.1 5.1 2.3 'Iris-virginica']
#  [5.8 2.7 5.1 1.9 'Iris-virginica']
#  [6.8 3.2 5.9 2.3 'Iris-virginica']
#  [6.7 3.3 5.7 2.5 'Iris-virginica']
#  [6.7 3.0 5.2 100 'Iris-virginica']
#  [6.3 2.5 5.0 1.9 'Iris-virginica']
#  [6.5 3.0 5.2 2.0 'Iris-virginica']
#  [6.2 3.4 5.4 2.3 'Iris-virginica']
#  [5.9 3.0 5.1 1.8 'Iris-virginica']]

# %%
               # 6.Impute the missing value data with KNN where N=2


#  Imputation with nearest values
data2 = pd.read_csv('dataset/irisMissingValue.csv')
data2= (data.iloc[:,:-1])
# creating a data frame from the list
Before_imputation = data2
#print dataset before imputation
print("Data Before performing imputation\n",Before_imputation)
# create an object for KNNImputer
imputer = KNNImputer(n_neighbors=2)
After_imputation = imputer.fit_transform(Before_imputation)
# print dataset after performing the operation
print("\n\nAfter performing imputation\n",After_imputation)

# %%
#                  7.delete records of dataset with missing values 

#  deletion of records with missing values
data2 = pd.read_csv('dataset/irisMissingValue.csv')
data2= (data.iloc[:,:-1])
print (len(data2))
data2 = data2.dropna() # drop rows with nan values
print (data2.isnull().sum())
print (data2)
print (data2.isnull().sum())
print (data2)

# %%
#           8.Transform the dataset to Min-Max Normalization

import math as m
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
data=pd.read_csv('dataset/iris.csv')
data2= (data.iloc[:,:-1])
print (data2.head())
print (data2.shape)
Scaler=MinMaxScaler()
ScaledData=Scaler.fit_transform (data2)
ScaledData=ScaledData.round(2)
print (ScaledData)
print (ScaledData.shape)

# %%
                   # 9.Transform the dataset to Z-Score Normalization

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data=pd.read_csv('dataset/iris.csv')
data2= (data.iloc[:,:-1])
normalized_data = scaler.fit_transform(data2)
print("Original data:\n \n \n", data2) # Flatten to print as 1D
print("Z-score normalized data (sklearn): \n \n \n", normalized_data)

# %%
            

    # 10.Take the age of patient from the hospital as follows 

import pandas as pd
import numpy as np
data=pd.read_csv('dataset/data8.csv')
print("Before: ")
print(data)
Label = pd.cut(x=data['Age'], bins=[0, 3, 7, 17, 63, 99],
labels=['Baby', 'Child', 'Teenage', 'Adult', 'Elderly'])
print("After: \n ", Label)
print("Categories: ")
print(Label.value_counts())
data = pd.concat([data, Label], axis=1)
print ("\n \n \n Merged Data \n \n", data)

# %%
                    # 11 Consider the following dataset and apply one hot encoding to the feature ‘city

import pandas as pd

# Read the dataset
data = pd.read_csv('dataset/city_data.csv')
print("Original Data:\n", data)

# Apply one-hot encoding to the 'city' column
data_encoded = pd.get_dummies(data, columns=['city'])

print("\nData after one-hot encoding:\n", data_encoded)
